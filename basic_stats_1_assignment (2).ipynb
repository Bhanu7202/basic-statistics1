# %% [markdown]
# # Descriptive Analytics for Numerical Columns

# %%
#Load the dataset into a programming environment
import pandas as pd
df=pd.read_csv('sales_data_with_discounts.csv')
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
#Identify numerical columns in the dataset.
numerical_columns = df.select_dtypes(include=['number']).columns
print(numerical_columns)
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
#Calculate the mean
import statistics as st
for column in df.select_dtypes(include='number').columns:
    mean = st.mean(df[column])
    print(f'mean of {column} is:{mean}')
# Out:
# mean of Volume is:5.066666666666666
# mean of Avg Price is:10453.433333333332
# mean of Total Sales Value is:33812.83555555555
# mean of Discount Rate (%) is:15.155241895330914
# mean of Discount Amount is:3346.499424342415
# mean of Net Sales Value is:30466.336131270138

# %%
#Calculate the median
for column in df.select_dtypes(include='number').columns:
    median = st.median(df[column])
    print(f'median of {column} is:{median}')
# Out:
# median of Volume is:4.0
# median of Avg Price is:1450.0
# median of Total Sales Value is:5700.0
# median of Discount Rate (%) is:16.57776564929597
# median of Discount Amount is:988.9337332382784
# median of Net Sales Value is:4677.788059301853

# %%
#Calculate the mode
for column in df.select_dtypes(include='number').columns:
    mode = st.mode(df[column])
    print(f'mode of {column} is:{mode}')
# Out:
# mode of Volume is:3
# mode of Avg Price is:8100
# mode of Total Sales Value is:24300
# mode of Discount Rate (%) is:11.654820286277229
# mode of Discount Amount is:21153.49881959317
# mode of Net Sales Value is:160346.50118040683

# %%
#Calculate the standard deviation
for column in df.select_dtypes(include='number').columns:
    sd = st.stdev(df[column])
    print(f'standard deviation of {column} is:{sd}')
# Out:
# standard deviation of Volume is:4.231602391213923
# standard deviation of Avg Price is:18079.90483993647
# standard deviation of Total Sales Value is:50535.07417255326
# standard deviation of Discount Rate (%) is:4.220602153325509
# standard deviation of Discount Amount is:4509.9029633539985
# standard deviation of Net Sales Value is:46358.65662406695

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # histograms

# %%
import matplotlib.pyplot as plt
for column in df.select_dtypes(include='number').columns:
    plt.hist(df[column],edgecolor='black',color='grey')
    plt.title(f'Boxplot for {column}')
    plt.xlabel(f'{column}')
    plt.ylabel('frequency')
    plt.show()

# %%
# finding skewness
from scipy.stats import skew
for column in df.select_dtypes(include='number').columns:
    k= df[column].skew()
    print(f'skew of {column} is:{k}')
# Out:
# skew of Volume is:2.731723626557714
# skew of Avg Price is:1.9088730767759727
# skew of Total Sales Value is:1.5347293238977937
# skew of Discount Rate (%) is:-1.0622943696988825
# skew of Discount Amount is:1.9130377339538271
# skew of Net Sales Value is:1.5408217575344376

# %%
skewness= df[numerical_columns].skew()
print('skewness of numerical columns is:\n' , skewness)
# Out:
# skewness of numerical columns is:
#  Volume               2.731724
# Avg Price            1.908873
# Total Sales Value    1.534729
# Discount Rate (%)   -1.062294
# Discount Amount      1.913038
# Net Sales Value      1.540822
# dtype: float64

# %%
''' A value between -1 & -0.5 (or) between 0.5 & 1 Indicades a moderately skewed distribution

    A value less than - 1.5 (or) grater than 1.5 indicates It is extremely skewed distribution'''
# Out:
# ' A value between -1 & -0.5 (or) between 0.5 & 1 Indicades a moderately skewed\xa0distribution\n\n    A value less than - 1.5 (or) grater than 1.5 indicates It is extremely skewed\xa0distribution'

# %%
from scipy.stats import kurtosis
kurtosis=df[numerical_columns].kurtosis()
print('kurtosis of numerical columnsis:\n',kurtosis)
# Out:
# kurtosis of numerical columnsis:
#  Volume               10.258547
# Avg Price             2.075655
# Total Sales Value     1.024916
# Discount Rate (%)    -0.178541
# Discount Amount       3.831186
# Net Sales Value       1.012468
# dtype: float64

# %%
''' A kurtosis grater than 2 suggests too peak distribution, while less than -2 indicates too flat one'''
# Out:
# ' A kurtosis grater than 2 suggests too peak distribution, while less than -2 indicates too flat one'

# %%
df.columns
df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %% [markdown]
# # Boxplots

# %%
import seaborn as sns
sns.boxplot(x='Day',y='Total Sales Value',data=df)
# Out:
# <Axes: xlabel='Day', ylabel='Total Sales Value'>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df)
plt.title('Boxplots for Numerical Variables')
plt.ylabel('Values')
plt.show()

# %%
# Alternatively, using seaborn for better visualization
for column in df.select_dtypes(include='number').columns:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot for {column}')
    plt.show()

# %% [markdown]
# # Bar Chart Analysis for Categorical Column

# %%
# Function to plot bar charts for categorical columns
def plot_categorical_distributions(df, categorical_columns):
    for column in categorical_columns:
        df[column].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
        plt.title(f'Distribution of {column}', fontsize=16)
        plt.xlabel(column, fontsize=14)
        plt.ylabel('Count', fontsize=14)
        plt.show()
# Extract categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Plot distributions
plot_categorical_distributions(df, categorical_columns)

# %% [markdown]
# # Standardization of Numerical Variables

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()
df1=df.copy()
numerical_columns1 = df1.select_dtypes(include=['number']).columns

# Standardize numerical columns
df1[numerical_columns1] = scaler.fit_transform(df1[numerical_columns1])

# Display the standardized dataset
print(df1)
print(df)
# Out:
#            Date       Day  SKU City    Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C  2.350029    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C  1.167129    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C  0.457388    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C  0.220808    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C -0.488932    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...       ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C -0.725512  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C  0.220808  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C -0.725512  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C -0.488932  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C -0.962092  Lifestyle  Jeera     M-Shoes
#
# ...

# %% [markdown]
# # Conversion of Categorical Data into Dummy Variables

# %%
df.nunique()
# Out:
# Date                  15
# Day                    7
# SKU                   30
# City                   1
# Volume                22
# BU                     3
# Brand                  9
# Model                 30
# Avg Price             25
# Total Sales Value    135
# Discount Rate (%)    450
# Discount Amount      450
# Net Sales Value      450
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
# Conversion of Categorical Data into Dummy Variables
df3 = pd.get_dummies(df, columns=['BU'],drop_first=True)
df3
# Out:
#            Date       Day  SKU City  Volume  Brand       Model  Avg Price  \
# 0    01-04-2021  Thursday  M01    C      15  RealU       RU-10      12100
# 1    01-04-2021  Thursday  M02    C      10  RealU   RU-9 Plus      10100
# 2    01-04-2021  Thursday  M03    C       7   YouM       YM-99      16100
# 3    01-04-2021  Thursday  M04    C       6   YouM  YM-99 Plus      20100
# 4    01-04-2021  Thursday  M05    C       3   YouM      YM-98        8100
# ..          ...       ...  ...  ...     ...    ...         ...        ...
# 445  15-04-2021  Thursday  L06    C       2  Jeera   M-Casuals       1300
# 446  15-04-2021  Thursday  L07    C       6   Viva   W-Western       2600
# 447  15-04-2021  Thursday  L08    C       2   Viva    W-Lounge       1600
# 448  15-04-2021  Thursday  L09    C       3  Jeera   M-Formals       1900
# 449  15-04-2021  Thursday  L10    C       1  Jeera     M-Shoes       3100
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value  \
# ...

# %%
# Conversion of Categorical Data into Dummy Variables
df2 = pd.get_dummies(df, columns=['City'])

# %%
df2.head()
# Out:
#          Date       Day  SKU  Volume       BU  Brand       Model  Avg Price  \
# 0  01-04-2021  Thursday  M01      15  Mobiles  RealU       RU-10      12100
# 1  01-04-2021  Thursday  M02      10  Mobiles  RealU   RU-9 Plus      10100
# 2  01-04-2021  Thursday  M03       7  Mobiles   YouM       YM-99      16100
# 3  01-04-2021  Thursday  M04       6  Mobiles   YouM  YM-99 Plus      20100
# 4  01-04-2021  Thursday  M05       3  Mobiles   YouM      YM-98        8100
#
#    Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value  \
# 0             181500          11.654820     21153.498820    160346.501180
# 1             101000          11.560498     11676.102961     89323.897039
# 2             112700           9.456886     10657.910157    102042.089843
# 3             120600           6.935385      8364.074702    112235.925298
# 4              24300          17.995663      4372.946230     19927.053770
#
#    City_C
# 0    True
# 1    True
# 2    True
# 3    True
# ...
